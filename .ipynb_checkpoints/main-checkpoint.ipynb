# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("Talent_Academy_Case_DT_2025.xlsx")

# %%
data.head()
# Out:
#    HastaNo  Yas Cinsiyet KanGrubu    Uyruk  \
# 0   145134   60    Kadın    0 Rh+  Türkiye
# 1   145135   28    Erkek    0 Rh+  Türkiye
# 2   145135   28    Erkek    0 Rh+  Türkiye
# 3   145135   28    Erkek    0 Rh+  Türkiye
# 4   145135   28    Erkek    0 Rh+  Türkiye
#
#                                       KronikHastalik  \
# 0  Becker Musküler Distrofisi, Hiportiroidizm, Ka...
# 1  Duchenne Musküler Distrofisi, Myastenia gravis...
# 2  Duchenne Musküler Distrofisi, Myastenia gravis...
# 3  Duchenne Musküler Distrofisi, Myastenia gravis...
# 4  Duchenne Musküler Distrofisi, Myastenia gravis...
#
#                                             Bolum Alerji  \
# 0  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    TOZ
# 1  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 2  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 3  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 4  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
#
#                                              Tanilar  \
# 0         Ayak bileği ve ayağın yüzeysel yaralanması
# 1  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 2  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 3  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 4  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
#
#                          TedaviAdi TedaviSuresi UygulamaYerleri UygulamaSuresi
# 0                      Ayak Bileği      5 Seans     Ayak Bileği      20 Dakika
# 1  Dorsalji -Boyun+trapez+skapular     15 Seans           Boyun      20 Dakika
# 2  Dorsalji -Boyun+trapez+skapular     15 Seans      Boyun,Sırt      20 Dakika
# 3  Dorsalji -Boyun+trapez+skapular     15 Seans           Boyun       5 Dakika
# 4  Dorsalji -Boyun+trapez+skapular     15 Seans      Boyun,Sırt      20 Dakika

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235 entries, 0 to 2234
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   HastaNo          2235 non-null   int64
#  1   Yas              2235 non-null   int64
#  2   Cinsiyet         2066 non-null   object
#  3   KanGrubu         1560 non-null   object
#  4   Uyruk            2235 non-null   object
#  5   KronikHastalik   1624 non-null   object
#  6   Bolum            2224 non-null   object
#  7   Alerji           1291 non-null   object
#  8   Tanilar          2160 non-null   object
#  9   TedaviAdi        2235 non-null   object
#  10  TedaviSuresi     2235 non-null   object
#  11  UygulamaYerleri  2014 non-null   object
#  12  UygulamaSuresi   2235 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 227.1+ KB

# %%
data.shape
# Out:
# (2235, 13)

# %%
data.columns
# Out:
# Index(['HastaNo', 'Yas', 'Cinsiyet', 'KanGrubu', 'Uyruk', 'KronikHastalik',
#        'Bolum', 'Alerji', 'Tanilar', 'TedaviAdi', 'TedaviSuresi',
#        'UygulamaYerleri', 'UygulamaSuresi'],
#       dtype='object')

# %%
data.describe()
# Out:
#              HastaNo          Yas
# count    2235.000000  2235.000000
# mean   145333.100224    47.327069
# std       115.214248    15.208634
# min    145134.000000     2.000000
# 25%    145235.000000    38.000000
# 50%    145331.000000    46.000000
# 75%    145432.000000    56.000000
# max    145537.000000    92.000000

# %%
data.describe(include="all").T
# Out:
#                   count unique  \
# HastaNo          2235.0    NaN
# Yas              2235.0    NaN
# Cinsiyet           2066      2
# KanGrubu           1560      8
# Uyruk              2235      5
# KronikHastalik     1624    220
# Bolum              2224     10
# Alerji             1291     38
# Tanilar            2160    367
# TedaviAdi          2235    244
# TedaviSuresi       2235     23
# UygulamaYerleri    2014     37
# UygulamaSuresi     2235     10
#
#                                                             top  freq  \
# HastaNo                                                     NaN   NaN
# Yas                                                         NaN   NaN
# Cinsiyet                                                  Kadın  1274
# KanGrubu                                                  0 Rh+   579
# Uyruk                                                   Türkiye  2173
# KronikHastalik                                 Myastenia gravis    38
# Bolum            Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi  2045
# Alerji                                                    Polen   198
# Tanilar                      DORSALJİ, DİĞER, LUMBOSAKRAL BÖLGE   149
# TedaviAdi                                Dorsalji -Boyun+trapez   231
# TedaviSuresi                                           15 Seans  1670
# UygulamaYerleri                                             Bel   528
# UygulamaSuresi                                        20 Dakika  1535
#
#                           mean         std       min       25%       50%  \
# HastaNo          145333.100224  115.214248  145134.0  145235.0  145331.0
# Yas                  47.327069   15.208634       2.0      38.0      46.0
# Cinsiyet                   NaN         NaN       NaN       NaN       NaN
# KanGrubu                   NaN         NaN       NaN       NaN       NaN
# Uyruk                      NaN         NaN       NaN       NaN       NaN
# KronikHastalik             NaN         NaN       NaN       NaN       NaN
# Bolum                      NaN         NaN       NaN       NaN       NaN
# Alerji                     NaN         NaN       NaN       NaN       NaN
# Tanilar                    NaN         NaN       NaN       NaN       NaN
# TedaviAdi                  NaN         NaN       NaN       NaN       NaN
# TedaviSuresi               NaN         NaN       NaN       NaN       NaN
# UygulamaYerleri            NaN         NaN       NaN       NaN       NaN
# UygulamaSuresi             NaN         NaN       NaN       NaN       NaN
#
#                       75%       max
# HastaNo          145432.0  145537.0
# Yas                  56.0      92.0
# Cinsiyet              NaN       NaN
# KanGrubu              NaN       NaN
# Uyruk                 NaN       NaN
# KronikHastalik        NaN       NaN
# Bolum                 NaN       NaN
# Alerji                NaN       NaN
# Tanilar               NaN       NaN
# TedaviAdi             NaN       NaN
# TedaviSuresi          NaN       NaN
# UygulamaYerleri       NaN       NaN
# UygulamaSuresi        NaN       NaN

# %%
data.isnull().sum()
# Out:
# HastaNo              0
# Yas                  0
# Cinsiyet           169
# KanGrubu           675
# Uyruk                0
# KronikHastalik     611
# Bolum               11
# Alerji             944
# Tanilar             75
# TedaviAdi            0
# TedaviSuresi         0
# UygulamaYerleri    221
# UygulamaSuresi       0
# dtype: int64

# %%
data.isnull().sum() / len(data) * 100
# Out:
# HastaNo             0.000000
# Yas                 0.000000
# Cinsiyet            7.561521
# KanGrubu           30.201342
# Uyruk               0.000000
# KronikHastalik     27.337808
# Bolum               0.492170
# Alerji             42.237136
# Tanilar             3.355705
# TedaviAdi           0.000000
# TedaviSuresi        0.000000
# UygulamaYerleri     9.888143
# UygulamaSuresi      0.000000
# dtype: float64

# %%
df = data.copy()

# %%
# "5 Seans" -> 5
df["TedaviSuresi_num_seans"] = df["TedaviSuresi"].str.extract("(\d+)").astype(float)

# %%
df["UygulamaSuresi_num_dk"] = df["UygulamaSuresi"].str.extract("(\d+)").astype(float)

# %%
df = df.drop(columns = ["TedaviSuresi", "UygulamaSuresi"])

# %%
df_grouped_gender = df.groupby("Cinsiyet")

# %%
df_grouped_gender.count()
# Out:
#           HastaNo   Yas  KanGrubu  Uyruk  KronikHastalik  Bolum  Alerji  \
# Cinsiyet
# Erkek         792   792       503    792             601    792     447
# Kadın        1274  1274       959   1274             907   1263     754
#
#           Tanilar  TedaviAdi  UygulamaYerleri  TedaviSuresi_num_seans  \
# Cinsiyet
# Erkek         775        792              691                     792
# Kadın        1216       1274             1162                    1274
#
#           UygulamaSuresi_num_dk
# Cinsiyet
# Erkek                       792
# Kadın                      1274

# %%
df_grouped_gender.describe()
# Out:
#          HastaNo                                                           \
#            count           mean         std       min       25%       50%
# Cinsiyet
# Erkek      792.0  145340.987374  119.195512  145135.0  145249.0  145345.0
# Kadın     1274.0  145324.771586  115.332970  145134.0  145227.5  145317.0
#
#                                  Yas             ... TedaviSuresi_num_seans  \
#                75%       max   count       mean  ...                    75%
# Cinsiyet                                         ...
# Erkek     145450.0  145536.0   792.0  47.265152  ...                   15.0
# Kadın     145425.0  145537.0  1274.0  47.945055  ...                   15.0
#
#                UygulamaSuresi_num_dk                                        \
#            max                 count       mean       std  min   25%   50%
# Cinsiyet
# Erkek     29.0                 792.0  16.325758  6.395909  5.0  10.0  20.0
# Kadın     37.0                1274.0  16.740973  6.199899  3.0  15.0  20.0
#
#
#            75%   max
# Cinsiyet
# Erkek     20.0  45.0
# Kadın     20.0  45.0
#
# [2 rows x 32 columns]

# %%
df_grouped_gender["Yas"].mean()
# Out:
# Cinsiyet
# Erkek    47.265152
# Kadın    47.945055
# Name: Yas, dtype: float64

# %%
df_grouped_blood_group = df.groupby("KanGrubu")

# %%
df_grouped_blood_group.count()
# Out:
#           HastaNo  Yas  Cinsiyet  Uyruk  KronikHastalik  Bolum  Alerji  \
# KanGrubu
# 0 Rh+         579  579       538    579             413    579     344
# 0 Rh-          26   26        26     26              25     26       3
# A Rh+         540  540       518    540             361    529     311
# A Rh-          53   53        43     53              41     53      31
# AB Rh+         80   80        80     80              70     80      32
# AB Rh-          8    8         8      8               3      8       8
# B Rh+         206  206       191    206             157    206     114
# B Rh-          68   68        58     68              55     68      23
#
#           Tanilar  TedaviAdi  UygulamaYerleri  TedaviSuresi_num_seans  \
# KanGrubu
# 0 Rh+         544        579              516                     579
# 0 Rh-          24         26               19                      26
# A Rh+         519        540              479                     540
# A Rh-          46         53               45                      53
# AB Rh+         80         80               56                      80
# AB Rh-          8          8                8                       8
# B Rh+         201        206              191                     206
# B Rh-          68         68               60                      68
#
#           UygulamaSuresi_num_dk
# KanGrubu
# 0 Rh+                       579
# 0 Rh-                        26
# A Rh+                       540
# A Rh-                        53
# AB Rh+                       80
# AB Rh-                        8
# B Rh+                       206
# B Rh-                        68

# %%
df_grouped_blood_group.describe()
# Out:
#          HastaNo                                                            \
#            count           mean         std       min        25%       50%
# KanGrubu
# 0 Rh+      579.0  145309.677029  113.441559  145134.0  145221.00  145294.0
# 0 Rh-       26.0  145213.423077   83.708625  145168.0  145169.75  145193.0
# A Rh+      540.0  145287.531481  111.052616  145138.0  145201.00  145257.0
# A Rh-       53.0  145288.320755   82.234836  145167.0  145240.00  145297.0
# AB Rh+      80.0  145318.212500  122.220458  145145.0  145237.75  145263.0
# AB Rh-       8.0  145423.875000  142.326022  145252.0  145252.00  145527.0
# B Rh+      206.0  145292.334951  113.351943  145142.0  145195.00  145260.0
# B Rh-       68.0  145291.882353  113.995618  145143.0  145236.00  145246.0
#
#                                 Yas             ... TedaviSuresi_num_seans  \
#                75%       max  count       mean  ...                    75%
# KanGrubu                                        ...
# 0 Rh+     145406.0  145533.0  579.0  47.984456  ...                  15.00
# 0 Rh-     145214.0  145490.0   26.0  45.346154  ...                  18.75
# A Rh+     145353.0  145537.0  540.0  49.216667  ...                  15.00
# A Rh-     145325.0  145475.0   53.0  49.566038  ...                  15.00
# AB Rh+    145465.0  145526.0   80.0  48.400000  ...                  15.00
# AB Rh-    145527.0  145527.0    8.0  35.625000  ...                  15.00
# B Rh+     145395.0  145522.0  206.0  51.970874  ...                  15.00
# B Rh-     145416.0  145521.0   68.0  42.323529  ...                  15.00
#
#                UygulamaSuresi_num_dk                                        \
#            max                 count       mean       std  min   25%   50%
# KanGrubu
# 0 Rh+     30.0                 579.0  16.321244  6.213370  5.0  10.0  20.0
# 0 Rh-     20.0                  26.0  18.076923  7.358930  5.0  15.0  20.0
# A Rh+     30.0                 540.0  16.477778  6.409746  5.0  10.0  20.0
# A Rh-     15.0                  53.0  16.981132  5.401177  5.0  15.0  20.0
# AB Rh+    15.0                  80.0  16.500000  5.703652  5.0  10.0  20.0
# AB Rh-    15.0                   8.0  16.250000  6.943651  5.0  10.0  20.0
# B Rh+     29.0                 206.0  16.228155  6.346990  3.0  10.0  20.0
# B Rh-     20.0                  68.0  17.426471  7.893538  5.0  15.0  20.0
#
#
#            75%   max
# KanGrubu
# 0 Rh+     20.0  45.0
# 0 Rh-     20.0  45.0
# A Rh+     20.0  45.0
# A Rh-     20.0  20.0
# AB Rh+    20.0  20.0
# AB Rh-    20.0  25.0
# B Rh+     20.0  45.0
# B Rh-     20.0  45.0
#
# [8 rows x 32 columns]

# %%
df_grouped_blood_group["Yas"].mean()
# Out:
# KanGrubu
# 0 Rh+     47.984456
# 0 Rh-     45.346154
# A Rh+     49.216667
# A Rh-     49.566038
# AB Rh+    48.400000
# AB Rh-    35.625000
# B Rh+     51.970874
# B Rh-     42.323529
# Name: Yas, dtype: float64

# %%
df_grouped_nationality = df.groupby("Uyruk")

# %%
df_grouped_nationality.count()
# Out:
#             HastaNo   Yas  Cinsiyet  KanGrubu  KronikHastalik  Bolum  Alerji  \
# Uyruk
# Arnavutluk       13    13        13        13              13     13       0
# Azerbaycan       12    12        12        12              12     12       7
# Libya            10    10        10         5              10     10       5
# Tokelau          27    27        27        27              27     27       0
# Türkiye        2173  2173      2004      1503            1562   2162    1279
#
#             Tanilar  TedaviAdi  UygulamaYerleri  TedaviSuresi_num_seans  \
# Uyruk
# Arnavutluk        7         13               10                      13
# Azerbaycan       12         12                6                      12
# Libya            10         10                6                      10
# Tokelau           0         27               16                      27
# Türkiye        2131       2173             1976                    2173
#
#             UygulamaSuresi_num_dk
# Uyruk
# Arnavutluk                     13
# Azerbaycan                     12
# Libya                          10
# Tokelau                        27
# Türkiye                      2173

# %%
df_grouped_nationality.describe()
# Out:
#            HastaNo                                                           \
#              count           mean         std       min       25%       50%
# Uyruk
# Arnavutluk    13.0  145481.000000    0.000000  145481.0  145481.0  145481.0
# Azerbaycan    12.0  145393.000000   67.970582  145338.0  145338.0  145338.0
# Libya         10.0  145474.500000   30.041638  145446.0  145446.0  145474.5
# Tokelau       27.0  145267.000000    0.000000  145267.0  145267.0  145267.0
# Türkiye     2173.0  145332.055223  115.446510  145134.0  145233.0  145330.0
#
#                                    Yas             ... TedaviSuresi_num_seans  \
#                  75%       max   count       mean  ...                    75%
# Uyruk                                              ...
# Arnavutluk  145481.0  145481.0    13.0  26.000000  ...                   15.0
# Azerbaycan  145470.0  145470.0    12.0  36.250000  ...                   15.0
# Libya       145503.0  145503.0    10.0  35.000000  ...                   20.0
# Tokelau     145267.0  145267.0    27.0  48.000000  ...                   30.0
# Türkiye     145430.0  145537.0  2173.0  47.564197  ...                   15.0
#
#                  UygulamaSuresi_num_dk                                        \
#              max                 count       mean       std  min   25%   50%
# Uyruk
# Arnavutluk  20.0                  13.0  17.307692  5.991447  5.0  15.0  20.0
# Azerbaycan  15.0                  12.0  17.083333  5.418123  5.0  17.5  20.0
# Libya       20.0                  10.0  18.000000  4.830459  5.0  20.0  20.0
# Tokelau     30.0                  27.0  18.148148  5.397319  5.0  20.0  20.0
# Türkiye     37.0                2173.0  16.539807  6.291192  3.0  10.0  20.0
#
#
#              75%   max
# Uyruk
# Arnavutluk  20.0  30.0
# Azerbaycan  20.0  20.0
# Libya       20.0  20.0
# Tokelau     20.0  30.0
# Türkiye     20.0  45.0
#
# [5 rows x 32 columns]

# %%
df_grouped_nationality["Yas"].mean()
# Out:
# Uyruk
# Arnavutluk    26.000000
# Azerbaycan    36.250000
# Libya         35.000000
# Tokelau       48.000000
# Türkiye       47.564197
# Name: Yas, dtype: float64

# %%
bins = [0, 16, 26, 40, 60, 75, np.inf]
labels = ["0-15", "16-25", "26-39", "40-59", "60-74","75+"]

# %%
df["age_group"] = pd.cut(
        df["Yas"],
    bins = bins,
    labels = labels,
    right=False, # sol dahil, sağ dahil değil [0,16) gibi
    include_lowest=True
)

# %%
df_grouped_age = df.groupby("age_group", observed=True)["Yas"].count()
ozet = df.groupby("age_group", observed=True).agg({
     "Yas": ["count", "mean", "min", "max"],
})

print(df_grouped_age)
print("**************************************")
print(ozet)
# Out:
# age_group
# 0-15       63
# 16-25     105
# 26-39     471
# 40-59    1157
# 60-74     346
# 75+        93
# Name: Yas, dtype: int64
# **************************************
#             Yas
#           count       mean min max
# age_group
# 0-15         63  10.396825   2  15
# 16-25       105  21.866667  16  25
# 26-39       471  34.847134  26  39
# 40-59      1157  48.220398  40  59
# 60-74       346  66.690751  60  74
# 75+          93  81.139785  75  92

# %%
def age_category(yas):
    if yas <= 15:
        return "Child"
    elif 16 <= yas <= 25:
        return "Young Adult"
    elif 26 <= yas <= 39:
        return "Early Adulthood"
    elif 40 <= yas <= 59:
        return "middle age"
    elif 60 <= yas <= 74:
        return "young old"
    else:
        return "old age"

# %%
df["age_category"] = df["Yas"].apply(age_category)

# %%
df_grouped_age_category = df.groupby("age_category")["age_category"].count()
print(df_grouped_age_category)
# Out:
# age_category
# Child                63
# Early Adulthood     471
# Young Adult         105
# middle age         1157
# old age              93
# young old           346
# Name: age_category, dtype: int64

# %%
sns.histplot(df["TedaviSuresi_num_seans"], kde=True, bins=30)
plt.title("Tedavi Süresi Dağılımı")
plt.show()

# %%
#Sayısal Değişkenlerin Dağılımı
num_cols = ["Yas", "TedaviSuresi_num_seans", "UygulamaSuresi_num_dk"]

df[num_cols].hist(bins=30, figsize=(12,6))
plt.show()

# %%
#Kategorik değişkenlerin dağılımı

cat_cols = ["Cinsiyet","KanGrubu","Uyruk", "Bolum","Alerji", "UygulamaYerleri"]

for col in cat_cols:
    plt.figure(figsize=(12,6))
    sns.countplot(x=col, data=df, order=df[col].value_counts().index)
    plt.title(f"{col} Dağılımı")
    plt.xticks(rotation=90)
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Sayısal Değişkenler Korelasyon Matrisi")
plt.show()

# %%
sns.scatterplot(x="Yas", y="TedaviSuresi_num_seans", data=df)
sns.scatterplot(x="UygulamaSuresi_num_dk", y="TedaviSuresi_num_seans", data=df)
# Out:
# <Axes: xlabel='Yas', ylabel='TedaviSuresi_num_seans'>

# %%
df.head()
# Out:
#    HastaNo  Yas Cinsiyet KanGrubu    Uyruk  \
# 0   145134   60    Kadın    0 Rh+  Türkiye
# 1   145135   28    Erkek    0 Rh+  Türkiye
# 2   145135   28    Erkek    0 Rh+  Türkiye
# 3   145135   28    Erkek    0 Rh+  Türkiye
# 4   145135   28    Erkek    0 Rh+  Türkiye
#
#                                       KronikHastalik  \
# 0  Becker Musküler Distrofisi, Hiportiroidizm, Ka...
# 1  Duchenne Musküler Distrofisi, Myastenia gravis...
# 2  Duchenne Musküler Distrofisi, Myastenia gravis...
# 3  Duchenne Musküler Distrofisi, Myastenia gravis...
# 4  Duchenne Musküler Distrofisi, Myastenia gravis...
#
#                                             Bolum Alerji  \
# 0  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    TOZ
# 1  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 2  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 3  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
# 4  Fiziksel Tıp Ve Rehabilitasyon,Solunum Merkezi    NaN
#
#                                              Tanilar  \
# 0         Ayak bileği ve ayağın yüzeysel yaralanması
# 1  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 2  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 3  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
# 4  Omuzun darbe sendromu,DORSALJİ, DİĞER, SERVİKO...
#
#                          TedaviAdi UygulamaYerleri  TedaviSuresi_num_seans  \
# 0                      Ayak Bileği     Ayak Bileği                     5.0
# 1  Dorsalji -Boyun+trapez+skapular           Boyun                    15.0
# 2  Dorsalji -Boyun+trapez+skapular      Boyun,Sırt                    15.0
# 3  Dorsalji -Boyun+trapez+skapular           Boyun                    15.0
# 4  Dorsalji -Boyun+trapez+skapular      Boyun,Sırt                    15.0
#
#    UygulamaSuresi_num_dk age_group     age_category
# 0                   20.0     60-74        young old
# 1                   20.0     26-39  Early Adulthood
# 2                   20.0     26-39  Early Adulthood
# 3                    5.0     26-39  Early Adulthood
# 4                   20.0     26-39  Early Adulthood

# %%
sns.boxplot(x="Cinsiyet", y="TedaviSuresi_num_seans", data=df)
# Out:
# <Axes: xlabel='Cinsiyet', ylabel='TedaviSuresi_num_seans'>

# %%
# Eksik değerlerin doldurulması
df["Cinsiyet"].fillna(df["Cinsiyet"].mode()[0], inplace=True)

# %%
# Çok fazla veri eksik olduğu için "Bilinmiyor" ile dolduruyoruz.
df["Alerji"].fillna("Bilinmiyor", inplace=True)
df["KanGrubu"].fillna("Bilinmiyor", inplace=True)
df["KronikHastalik"].fillna("Bilinmiyor", inplace=True)
df["UygulamaYerleri"].fillna("Bilinmiyor", inplace=True)

# %%
# Az veri eksik olduğu için en sık değer ile dolduruyoruz.
df["Bolum"].fillna(df["Bolum"].mode()[0], inplace=True)
df["Tanilar"].fillna(df["Tanilar"].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# HastaNo                   0
# Yas                       0
# Cinsiyet                  0
# KanGrubu                  0
# Uyruk                     0
# KronikHastalik            0
# Bolum                     0
# Alerji                    0
# Tanilar                   0
# TedaviAdi                 0
# UygulamaYerleri           0
# TedaviSuresi_num_seans    0
# UygulamaSuresi_num_dk     0
# age_group                 0
# age_category              0
# dtype: int64

# %%
# Kronik hastalık sayısı
df["KronikHastalikSayisi"] = df["KronikHastalik"].apply(lambda x: len(str(x).split(",")) if x!="Bilinmiyor" else 0)

# Örnek: Yaygın hastalıklar için flag
df["Diyabet"] = df["KronikHastalik"].str.contains("Diyabet", na=False).astype(int)
df["Hipertansiyon"] = df["KronikHastalik"].str.contains("Hipertansiyon", na=False).astype(int)

# %%
# Tani sayısı
df["TaniSayisi"] = df["Tanilar"].apply(lambda x: len(str(x).split(",")) if x!="Bilinmiyor" else 0)

# Örnek grup: Omurga rahatsızlığı
df["OmurgaSorunu"] = df["Tanilar"].str.contains("Bel|Boyun|Omurga", na=False).astype(int)

# %%
df["AlerjiVarMi"] = (df["Alerji"]!="Bilinmiyor").astype(int)

# %%
df["UygulamaYeriSayisi"] = df["UygulamaYerleri"].apply(lambda x: len(str(x).split(",")) if x!="Bilinmiyor" else 0)

# %%
df["TedaviYogunlugu"] = df["TedaviSuresi_num_seans"] * df["UygulamaSuresi_num_dk"]

# %%
df = pd.get_dummies(df, columns=["Cinsiyet","KanGrubu","Uyruk","Bolum","Alerji","UygulamaYerleri"], drop_first=True)
